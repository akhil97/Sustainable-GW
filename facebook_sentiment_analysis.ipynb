# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy
# !pip install sklearn
# !pip install tensorflow
# !pip install keras
# Out:
# ...
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
# ...

# %%
import nltk
nltk.download('all')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

from nltk.stem import WordNetLemmatizer

import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/modupeolafagbenro/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/modupeolafagbenro/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/modupeolafagbenro/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/modupeolafagbenro/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/modupeolafagbenro/nltk_data...
# ...

# %%
import pandas as pd
data = pd.read_csv('apify_group_scrape.csv')
print(data.head())
# Out:
#                    Poster  Comments                      time  Reactions  \
# 0          Michelle Scott         7  2023-08-15T00:55:37.000Z         94
# 1  Paulette Planidin West        11  2023-08-14T08:24:57.000Z         68
# 2         Trinity Bourque        11  2023-09-06T19:35:49.000Z          2
# 3        Elizabeth Kikoak         9  2023-08-14T13:21:37.000Z         11
# 4           Brenda Breton         8  2023-08-27T06:26:32.000Z         14
#
#    Reposts                                            Content
# 0        0       Daniel Scott and I made it out and are safe.
# 1        0  Brian, Teagan & I (oh and Snoopy) are safe in ...
# 2        0  does anyone kno where Timmy Nadaray may be sta...
# 3        0    Anyone know if Lee John Kikoak got on a flight?
# 4        0  I am safe and comfy Shaw’s Point Resort.  Beau...

# %%
print(data.columns)
# Out:
# Index(['Poster', 'Comments', 'time', 'Reactions', 'Reposts', 'Content'], dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
print(data.isnull)
# Out:
# <bound method DataFrame.isnull of                      Poster  Comments                      time  Reactions  \
# 0            Michelle Scott         7  2023-08-15T00:55:37.000Z         94
# 1    Paulette Planidin West        11  2023-08-14T08:24:57.000Z         68
# 2           Trinity Bourque        11  2023-09-06T19:35:49.000Z          2
# 3          Elizabeth Kikoak         9  2023-08-14T13:21:37.000Z         11
# 4             Brenda Breton         8  2023-08-27T06:26:32.000Z         14
# ..                      ...       ...                       ...        ...
# 400            Kathy Lepine         2  2023-08-17T14:12:42.000Z          4
# 401         Lizzie Cardinal         0  2023-08-17T05:41:27.000Z          4
# 402           Sadetło Scott         1  2023-08-17T05:18:04.000Z          0
# 403            Ginger Milne         4  2023-08-17T05:28:03.000Z         15
# 404            Tanya Ashley        15  2023-08-16T21:32:55.000Z          1
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Poster       0
# Comments     0
# time         0
# Reactions    0
# Reposts      0
# Content      0
# dtype: int64

# %%
print(data.iloc[:, 3:4])
print(data.iloc[:, 0:1])
# Out:
#        comments
# 0   21 comments
# 1   28 comments
# 2    2 comments
# 3   57 comments
# 4   15 comments
# ..          ...
# 94      1 share
# 95      1 share
# 96            0
# 97   2 comments
# 98  18 comments
#
# [99 rows x 1 columns]
#                                                poster
# 0                           Yellowknife House Sitting
# 1           Yellowknife's Rants & Raves 2.0 (Rated E)
# 2      Families With Pets Evacuating Yellowknife 2023
# 3                                          Gracie Ann
# 4                                      Alannah Monica
# ..                                                ...
# 94                        Yellowknife Women's Society
# 95  Concerned Yellowknife Residents for a Day Shel...
# 96                                          Anonymous
# 97                               Wesclean Yellowknife
# 98                           Mahalia Yakeleya Newmark
#
# [99 rows x 1 columns]

# %% [markdown]
# # Data pre-processing

# %%
def preprocess_text(text):

    # Tokenize the text

    tokens = word_tokenize(text.lower())




    # Remove stop words

    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]




    # Lemmatize the tokens

    lemmatizer = WordNetLemmatizer()

    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]




    # Join the tokens back into a string

    processed_text = ' '.join(lemmatized_tokens)

    return processed_text

# %%
data['Content'] = data['Content'].apply(preprocess_text)
print(data['Content'])
# Out:
# 0                               daniel scott made safe .
# 1      brian , teagan & ( oh snoopy ) safe grimshaw n...
# 2      anyone kno timmy nadaray may staying ? asking ...
# 3               anyone know lee john kikoak got flight ?
# 4      safe comfy shaw ’ point resort . beautiful pri...
#                              ...
# 400    new evacuation center register leduc recreatio...
# 401                      paddle prairie métis settlement
# 402    note : valleyview centre changed - see new inf...
# 403    wanted put wifi . still hay river . right fire...
# 404    anyone know approximately cell service resume ...
# Name: Content, Length: 405, dtype: object

# %% [markdown]
# #Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd



# Initialize NLTK sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Create get_sentiment function
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    compound_score = scores['compound']
    
    if compound_score > 0.05:
        return 'positive'
    elif compound_score < -0.05:
        return 'negative'
    else:
        return 'neutral'

# Apply get_sentiment function to the 'Content' column of the 'dat' DataFrame
data['sentiment'] = data['Content'].apply(get_sentiment)

# Print the updated data with sentiment
print(data[['Content', 'sentiment']])
# Out:
#                                                Content sentiment
# 0                             daniel scott made safe .  positive
# 1    brian , teagan & ( oh snoopy ) safe grimshaw n...  positive
# 2    anyone kno timmy nadaray may staying ? asking ...   neutral
# 3             anyone know lee john kikoak got flight ?   neutral
# 4    safe comfy shaw ’ point resort . beautiful pri...  positive
# ..                                                 ...       ...
# 400  new evacuation center register leduc recreatio...   neutral
# 401                    paddle prairie métis settlement   neutral
# 402  note : valleyview centre changed - see new inf...   neutral
# 403  wanted put wifi . still hay river . right fire...  negative
# 404  anyone know approximately cell service resume ...   neutral
#
# [405 rows x 2 columns]

# %%
data['sentiment'].unique()
# Out:
# array(['positive', 'neutral', 'negative'], dtype=object)

# %%
# Change the value of 0 to negative string and 1 to positive string in data['sentiment']

data['sentiment'] = data['sentiment'].replace([0, 1, 2], ['negative', 'neural', 'positive'])

# %%
import matplotlib.pyplot as plt


# Plot sentiment distribution
plt.figure(figsize=(8, 6))
data['sentiment'].value_counts().plot(kind='bar', color=['green', 'blue', 'red'])
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Convert 'time' column to datetime
data['time'] = pd.to_datetime(data['time'])

# Plot sentiment trend over time
plt.figure(figsize=(10, 6))
plt.plot(data['sentiment'], data['time'], marker='o',  color='b')
plt.xlabel('time')
plt.ylabel('sentiment')
plt.title('Sentiment Trend Over Time')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'time' column to datetime
data['time'] = pd.to_datetime(data['time'])

# Plot sentiment trend over time
sns.lineplot(data, x='time', y='sentiment')
plt.xlabel('time')
plt.ylabel('sentiment')
plt.title('Sentiment Trend Over Time')
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt

# Convert 'time' column to datetime
data['time'] = pd.to_datetime(data['time'])

# Plot sentiment trend over time
plt.figure(figsize=(10, 6))
plt.plot(data['time'],  marker='o', linestyle='-', color='b')
plt.xlabel('Time')
plt.title('Sentiment Trend Over Time')
plt.grid(True)
plt.show()

# %%
print(data['Reactions'])
# Out:
# 0      94
# 1      68
# 2       2
# 3      11
# 4      14
#        ..
# 400     4
# 401     4
# 402     0
# 403    15
# 404     1
# Name: Reactions, Length: 405, dtype: int64

# %%
print(data['Reactions'].dtype)
# Out:
# int64

# %%
import matplotlib.pyplot as plt

# Convert 'time' column to datetime
data['time'] = pd.to_datetime(data['time'])

# Plot sentiment trend over time
plt.figure(figsize=(10, 6))
plt.plot(data['time'], data['Reactions'], marker='o', linestyle='-', color='b')
plt.xlabel('Time')
plt.title('Peoples Reaction Trend Over Time')
plt.grid(True)
plt.show()

# %%
# !pip install wordcloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


# Combine all content into a single string
text = " ".join(i for i in data['Content'])

# Create a word cloud
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud from Dataset Content")
plt.show()
