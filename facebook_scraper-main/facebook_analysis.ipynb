# %%
# read the file
import pandas as pd
nodate_df = pd.read_csv('/content/drive/MyDrive/yellowknife analysis/datasets/facebook data/sam_scrap_facebook.csv')

# %%
print(nodate_df.info())
print('*'*100)
print(nodate_df.shape)
print('*'*100)
print(nodate_df.isnull().sum())
print('*'*100)
print(nodate_df.describe())
print('*'*100)
nodate_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Content    950 non-null    object
#  1   Reactions  809 non-null    object
#  2   Comments   552 non-null    object
#  3   Reposts    552 non-null    object
#  4   Poster     927 non-null    object
#  5   Location   145 non-null    object
# dtypes: object(6)
# memory usage: 44.7+ KB
# None
# ****************************************************************************************************
# (950, 6)
# ****************************************************************************************************
# Content        0
# Reactions    141
# Comments     398
# Reposts      398
# Poster        23
# Location     805
# dtype: int64
# ****************************************************************************************************
#                                                   Content Reactions  \
# count                                                 950       809
# unique                                                932       220
# top     N.W.T. officials say start planning now for li...       1.0
# freq                                                    2        43
#
#          Comments    Reposts    Poster         Location
# count         552        552       927              145
# unique         64         64       585               40
# top     1 comment  1 comment  NWT Fire  Yellowknife, NT
# freq           91         91        40               87
# ****************************************************************************************************
#                                                Content Reactions     Comments  \
# 0    H here!i became a full-time housesitter as of ...        66  21 comments
# 1    We’ve put together a timeline of our experienc...        43   4 comments
# 2    Hello to our Yellowknife clients. We have rece...         6   5 comments
# 3    *Please note due to evacuation orders to both ...         2          NaN
# 4    As wildfires continue to spread, we are seeing...        38  14 comments
# ..                                                 ...       ...          ...
# 945  Yellowknife Canada City empties as thousands f...       1.0    1 comment
# 946  https://thewesterner.blogspot.com/.../wildfire...       1.0          NaN
# 947  Cool! You can buy a fire? Seems it comes with ...       9.0   3 comments
# 948  The City of Yellowknife and a nearby First Nat...     341.0          NaN
# 949  The last two weeks have been stressful, emotio...       NaN          NaN
#
#          Reposts                             Poster Location
# 0    21 comments          Yellowknife House Sitting      NaN
# 1     4 comments        Yellowknife Women's Society      NaN
# 2     5 comments       Avid Insurance Group - North      NaN
# 3            NaN     Norland Insurance Agencies Ltd      NaN
# 4    14 comments                 The Explorer Hotel      NaN
# ..           ...                                ...      ...
# 945    1 comment                     Carlisle Dixon      NaN
# 946          NaN  The Westerner - News & Commentary      NaN
# 947   3 comments                   Suzanne Carriere      NaN
# 948          NaN                           CTV News      NaN
# 949          NaN                       Rebecca Alty      NaN
#
# [950 rows x 6 columns]

# %%
# data cleaning and data preprocessing for nodate_df
# remove the column for location
nodate_df = nodate_df.drop('Location', axis=1)
# impute the missing values for other columns
nodate_df['Reactions'] = nodate_df['Reactions'].fillna('0')
nodate_df['Comments'] = nodate_df['Comments'].fillna('0 comments')
nodate_df['Reposts'] = nodate_df['Reposts'].fillna('0 comments')
nodate_df['Poster'] = nodate_df['Poster'].fillna('unknown')

# %%
# prompt: select first string of column comments and reposts and stanarized the columns into integers

nodate_df['Comments'] = nodate_df['Comments'].str.split().str.get(0).astype(int)
nodate_df['Reposts'] = nodate_df['Reposts'].str.split().str.get(0).astype(int)

# %%
# prompt: find the rows where the reactions column contain 'K'

k_reactions_df = nodate_df[nodate_df['Reactions'].str.contains('K', na=False)]
k_reactions_df
# Out:
#                                                Content Reactions  Comments  \
# 47   Well when most people hear about an evacuation...      3.8K       289
# 226  Over the past two days, thousands of Yellowkni...      1.1K       649
#
#      Reposts           Poster
# 47       289  Alex Debogorski
# 226      649   Justin Trudeau

# %%
# prompt: for the nodate_df['Reactions'] where it contains K remove K

import re
nodate_df['Reactions'] = nodate_df['Reactions'].apply(lambda x: re.sub('[K]', '', x))
nodate_df['Reactions'] = nodate_df['Reactions'].astype(float)

# %%
nodate_df.loc[[47, 226], 'Reactions'] = nodate_df.loc[[47, 226], 'Reactions'] * 1000

# %%
nodate_df.loc[[47, 226], 'Reactions']
# Out:
# 47     3800.0
# 226    1100.0
# Name: Reactions, dtype: float64

# %%
nodate_df
# Out:
#                                                Content  Reactions  Comments  \
# 0    H here!i became a full-time housesitter as of ...       66.0        21
# 1    We’ve put together a timeline of our experienc...       43.0         4
# 2    Hello to our Yellowknife clients. We have rece...        6.0         5
# 3    *Please note due to evacuation orders to both ...        2.0         0
# 4    As wildfires continue to spread, we are seeing...       38.0        14
# ..                                                 ...        ...       ...
# 945  Yellowknife Canada City empties as thousands f...        1.0         1
# 946  https://thewesterner.blogspot.com/.../wildfire...        1.0         0
# 947  Cool! You can buy a fire? Seems it comes with ...        9.0         3
# 948  The City of Yellowknife and a nearby First Nat...      341.0         0
# 949  The last two weeks have been stressful, emotio...        0.0         0
#
#      Reposts                             Poster
# 0         21          Yellowknife House Sitting
# 1          4        Yellowknife Women's Society
# 2          5       Avid Insurance Group - North
# 3          0     Norland Insurance Agencies Ltd
# 4         14                 The Explorer Hotel
# ..       ...                                ...
# 945        1                     Carlisle Dixon
# 946        0  The Westerner - News & Commentary
# 947        3                   Suzanne Carriere
# 948        0                           CTV News
# 949        0                       Rebecca Alty
#
# [950 rows x 5 columns]

# %%
# data preprocessing for the content column
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# %% text preprocessing
# Remove the punctuation,lowercase the text and remove the stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
def text_preprocessing(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'https?://[A-Za-z0-9./]*', '', text)
    text = re.sub(r'RT @[\w]*:', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    text = [i for i in text if not i in stop_words]
    lemmatizer = WordNetLemmatizer()
    text = [lemmatizer.lemmatize(word) for word in text]
    return text
def remove_http(text):
    text = [i for i in text if 'http' not in i]
    text = [i for i in text if 'https' not in i]
    text = [i for i in text if 'yellowknife' not in i]
    return ' '.join(text)

#%%
# Apply the text preprocessing function to the text column
nodate_df['Content'] = nodate_df['Content'].apply(text_preprocessing)
# %%
nodate_df['Content'] = nodate_df['Content'].apply(remove_http)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nodate_df
# Out:
#                                                Content  Reactions  Comments  \
# 0    h herei became fulltime housesitter august st ...       66.0        21
# 1    ’ put together timeline experience evacuation ...       43.0         4
# 2    hello client received updated information insu...        6.0         5
# 3    please note due evacuation order hay river off...        2.0         0
# 4    wildfire continue spread seeing influx displac...       38.0        14
# ..                                                 ...        ...       ...
# 945  canada city empty thousand flee huge wildfire ...        1.0         1
# 946                                            trigger        1.0         0
# 947  cool buy fire seems come helicopter tanker wil...        9.0         3
# 948  city nearby first nation said friday wildfire ...      341.0         0
# 949  last two week stressful emotional challenging ...        0.0         0
#
#      Reposts                             Poster
# 0         21          Yellowknife House Sitting
# 1          4        Yellowknife Women's Society
# 2          5       Avid Insurance Group - North
# 3          0     Norland Insurance Agencies Ltd
# 4         14                 The Explorer Hotel
# ..       ...                                ...
# 945        1                     Carlisle Dixon
# 946        0  The Westerner - News & Commentary
# 947        3                   Suzanne Carriere
# 948        0                           CTV News
# 949        0                       Rebecca Alty
#
# [950 rows x 5 columns]

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
access_token = "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"

# model = AutoModel.from_pretrained("private/model", token=access_token)
# Preprocess text (username and link placeholders)
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL,token=access_token)
# model.save_pretrained(MODEL)
text = nodate_df['Content'][2]
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = config.id2label[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 1) neutral 0.8597
# 2) negative 0.1092
# 3) positive 0.0311

# %%
def sentiment_analysis(text):
  encoded_input = tokenizer(text, return_tensors='pt')
  output = model(**encoded_input)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)
  ranking = np.argsort(scores)
  ranking = ranking[::-1]
  sentiment = config.id2label[ranking[0]]
  return sentiment

nodate_df['sentiment'] = nodate_df['Content'].apply(sentiment_analysis)

# %%
nodate_df
# Out:
#                                                Content  Reactions  Comments  \
# 0    h herei became fulltime housesitter august st ...       66.0        21
# 1    ’ put together timeline experience evacuation ...       43.0         4
# 2    hello client received updated information insu...        6.0         5
# 3    please note due evacuation order hay river off...        2.0         0
# 4    wildfire continue spread seeing influx displac...       38.0        14
# ..                                                 ...        ...       ...
# 945  canada city empty thousand flee huge wildfire ...        1.0         1
# 946                                            trigger        1.0         0
# 947  cool buy fire seems come helicopter tanker wil...        9.0         3
# 948  city nearby first nation said friday wildfire ...      341.0         0
# 949  last two week stressful emotional challenging ...        0.0         0
#
#      Reposts                             Poster sentiment
# 0         21          Yellowknife House Sitting   neutral
# 1          4        Yellowknife Women's Society   neutral
# 2          5       Avid Insurance Group - North   neutral
# 3          0     Norland Insurance Agencies Ltd   neutral
# 4         14                 The Explorer Hotel   neutral
# ..       ...                                ...       ...
# 945        1                     Carlisle Dixon  negative
# 946        0  The Westerner - News & Commentary   neutral
# 947        3                   Suzanne Carriere   neutral
# 948        0                           CTV News   neutral
# 949        0                       Rebecca Alty  negative
#
# [950 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
nodate_df.groupby('sentiment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from wordcloud import WordCloud
positive_words = ' '.join(nodate_df[nodate_df['sentiment'] == 'positive']['Content'].tolist())
wordcloud = WordCloud(width=800, height=400).generate(positive_words)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Sentiment Word Cloud - facebook nodate_df')
plt.show()

negative_words = ' '.join(nodate_df[nodate_df['sentiment'] == 'negative']['Content'].tolist())
wordcloud = WordCloud(width=800, height=400).generate(negative_words)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Sentiment Word Cloud - nodate_df')
plt.show()

# %%
# show the top 10 rows in df where it get the most reactions comments and repost

nodate_df.sort_values(by=['Reactions', 'Comments', 'Reposts'], ascending=False).head(10)
# Out:
#                                                Content  Reactions  Comments  \
# 47   well people hear evacuation order hometown sta...     3800.0       289
# 226  past two day thousand resident forced evacuate...     1100.0       649
# 225  guitar player transport squadron vocalist tact...      959.0        72
# 727  waking news entire city canada ’ northwest ter...      810.0       181
# 266  selfies everyone international film festival g...      657.0        12
# 659  wildfire burning control widen canada evacuati...      645.0         3
# 100  think need take serious look treated alberta e...      583.0        56
# 503  rochdi ’ independent open pmpm daily help supp...      560.0        38
# 403  class az driver interested joining team paid t...      453.0        55
# 188  thinking people facing evacuation firefighter ...      372.0       323
#
#      Reposts                                             Poster sentiment
# 47       289                                    Alex Debogorski   neutral
# 226      649                                     Justin Trudeau   neutral
# 225       72                           Royal Canadian Air Force   neutral
# 727      181                                         Ginger Zee   neutral
# 266       12                                     Christina King  positive
# 659        3                                Lisa Buckley-Fezard   neutral
# 100       56          Yellowknife's Rants & Raves 2.0 (Rated E)   neutral
# 503       38  Your Independent Grocer - 250 Old Airport Road...   neutral
# 403       55                                          KAGCanada   neutral
# 188      323                                   Pierre Poilievre   neutral

# %%
date_df = pd.read_csv('/content/drive/MyDrive/yellowknife analysis/datasets/facebook data/UPDATED_apify_group_scrape.csv')

# %%
# date_df
print(date_df.info())
print('*'*100)
print(date_df.shape)
print('*'*100)
print(date_df.isnull().sum())
print('*'*100)
print(date_df.describe())
print('*'*100)
date_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Poster                   405 non-null    object
#  1   Comments                 405 non-null    int64
#  2   Reactions                405 non-null    int64
#  3   time                     405 non-null    object
#  4   Reposts                  405 non-null    int64
#  5   Content                  405 non-null    object
#  6   topComments_0_comments   98 non-null     float64
#  7   topComments_0_time       271 non-null    object
#  8   topComments_0_reactions  271 non-null    float64
#  9   topComments_0_poster     271 non-null    object
#  10  topComments_0_content    265 non-null    object
#  11  topComments_1_comments   68 non-null     float64
#  12  topComments_1_time       206 non-null    object
#  13  topComments_1_reactions  206 non-null    float64
#  14  topComments_1_poster     206 non-null    object
#  15  topComments_1_content    201 non-null    object
# dtypes: float64(4), int64(3), object(9)
# memory usage: 50.8+ KB
# None
# ****************************************************************************************************
# (405, 16)
# ****************************************************************************************************
# Poster                       0
# Comments                     0
# Reactions                    0
# time                         0
# Reposts                      0
# Content                      0
# topComments_0_comments     307
# topComments_0_time         134
# topComments_0_reactions    134
# topComments_0_poster       134
# topComments_0_content      140
# topComments_1_comments     337
# topComments_1_time         199
# topComments_1_reactions    199
# topComments_1_poster       199
# topComments_1_content      204
# dtype: int64
# ****************************************************************************************************
#          Comments   Reactions  Reposts  topComments_0_comments  \
# count  405.000000  405.000000    405.0               98.000000
# mean     6.133333   25.881481      0.0                2.418367
# std      9.936780   43.617439      0.0                1.855188
# min      0.000000    0.000000      0.0                1.000000
# 25%      0.000000    2.000000      0.0                1.000000
# 50%      3.000000    6.000000      0.0                2.000000
# 75%      8.000000   34.000000      0.0                3.000000
# max     93.000000  257.000000      0.0               10.000000
#
#        topComments_0_reactions  topComments_1_comments  \
# count               271.000000               68.000000
# mean                  1.837638                2.132353
# std                   3.234568                1.984300
# min                   0.000000                1.000000
# 25%                   0.000000                1.000000
# 50%                   1.000000                1.000000
# 75%                   2.000000                3.000000
# max                  23.000000               11.000000
#
#        topComments_1_reactions
# count               206.000000
# mean                  1.266990
# std                   1.955998
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                
#      topComments_1_reactions topComments_1_poster  \
# 0                        0.0     Barb Hunt-Atwell
# 1                        0.0           Vita Morin
# 2                        3.0         Jeannie Shae
# 3                        1.0   June Summer Kikoak
# 4                        0.0       Margaret Shott
# ..                       ...                  ...
# 400                      0.0      Scott Clouthier
# 401                      NaN                  NaN
# 402                      NaN                  NaN
# 403                      0.0            Judy Zhou
# 404                      2.0       Darren Tuccaro
#
#                                  topComments_1_content
# 0                                                   🥰💞
# 1                Are you here in Peace River Paulette?
# 2    He is here in Grand Prairie and staying at the...
# 3    Was too stubborn to leave, talked to him yeste...
# 4                                    Are you fishing 🎣
# ..                                                 ...
# 400             Leduc is only for South Slave evacuees
# 401                                                NaN
# 402                                                NaN
# 403                                         Stay safe!
# 404  no cell service from fort providence to steen ...
#
# [405 rows x 16 columns]

# %%
# data preprocessing of time column
date_df['time'] = pd.to_datetime(date_df['time']).dt.strftime('%b %d')

# %%
# data preprocessing of Content column
date_df['Content'] = date_df['Content'].apply(text_preprocessing)
date_df['Content'] = date_df['Content'].apply(remove_http)

# %%
date_df

# %%
def sentiment_analysis(text, row_index, max_length=512):
    try:
        tokens = tokenizer.encode(text, add_special_tokens=True)
        if len(tokens) > max_length:
            print(f"Error: Text exceeds the maximum length of {max_length} tokens at row {row_index}")
            return 'nan'
        # Proceed with sentiment analysis if the text is within the limit
        encoded_input = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        ranking = np.argsort(scores)[::-1]
        sentiment = config.id2label[ranking[0]]
        return sentiment
    except Exception as e:
        return f"Error: An exception occurred at row {row_index}: {str(e)}"

date_df['sentiment'] = date_df.apply(lambda row: sentiment_analysis(row['Content'], row.name), axis=1)
# Out:
# Error: Text exceeds the maximum length of 512 tokens at row 302

# %%
date_df.iloc[302]['Content']
# Out:
# '⚠️ fire information update – aug pm ⚠️ wood buffalo complex previously park canada fire alberta wildfire mnz nwt s yesterday evening government northwest territory park canada alberta wildfire made decision enter unified command unified command mean shared responsibility command among agency incident commander decision made originally wildfire wood buffalo national park breached northwest territory alberta border wildfire cross jurisdictional boundary multiple agency may start working close quarter establishing unified command help keep objective communication clear creates safer environment work wildfire agency know resource working also allows better utilization resource operation work tandem rather working around ➡️wood buffalo complex currently hectare size located approximately km south fort smith nwt km south fort fitzgerald ab ➡️collectively personnel helicopter piece heavy equipment responding wood buffalo complex today thanks increased humidity light wind wood buffalo complex wildfire wood buffalo national park little growth past two day last night received mm precipitation fort smith today ’ priority continues placed effort prevent fire impacting fort smith fort smith airport fort fitzgerald smith ’ landing first nation thebacha bordertown halfway bell rock fire guard established around part fire east side highway near salt river run road today crew finishing work along guard extinguish hot spot help helicopter bucketing old fire guard reestablished running west highway west fort smith connected airport aid community protection also creating fire guard around fort fitzgerald smith ’ landing first nation crew continue examine opportunity conduct strategic microignition effort near highway gently bring fire pavement removing fuel prior approaching fire slow spread fire join burned area ⚠️it remains unsafe resident return fort smith fort fitzgerald town fort smith fort fitzgerald declared state local emergency remains evacuation order order issued public safety highway currently closed hay river fort smith due safety concern fire activity limited visibility please visit smith ’ landing first nation ’ facebook evacuation information smith landing first nation please visit fort smith website uptodate emergency planning information town fort smith northwest territory canada order reduce unnecessary stress limited critical resource community fort smith potable water communication line health care service local power supply nonessential first responder relocated nearby location earlier week essential first responder continue remain place 🔥 fire fire park canada continue actively monitor fire potential impact effort address fire 🔥 fire wood buffalo national park fire park currently pose risk public safety time continue monitor required ⚠️due ongoing fire behaviour fire operation area pine lake road recreation area remain closed unsafe area time ℹ️additional information information wildfire within wood buffalo national park visit fire information wildfire within northwest territory visit northwest territory fire information information wildfire within alberta visit alberta wildfire status dashboard uptodate road condition visit gnwt highway condition website ☀️weather today ’ high degree celsius relative humidity percent wind coming southwest kmh cold front move region expected bring wind gust kmh change wind direction northwest possible shower temporary measure fibre optic line please report wildfire suspicious smoke wood buffalo national park fire duty officer via email wbnpfirefeupnwbgcca ℹ️for information contact michelle macullo fire information officer wood buffalo national park wbnpfirefeupnbwbgcca emily smith wildfire information officer fort mcmurray forest area emilysmithabca'

# %%
date_df.loc[302, 'sentiment'] = 'neutral'

# %%
date_df['sentiment'].value_counts()
# Out:
# sentiment
# neutral     315
# positive     77
# negative     13
# Name: count, dtype: int64

# %%
date_df

# %%
from matplotlib import pyplot as plt
import seaborn as sns
date_df.groupby('sentiment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_sentiment_count = date_df.groupby(['time', 'sentiment']).size().unstack()
df_sentiment_count.plot(kind='line', figsize=(12, 6))
plt.title('Sentiment Analysis of Facebook post Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Posts')
plt.legend(title='Sentiment')
plt.show()

# %%
from wordcloud import WordCloud
positive_words = ' '.join(date_df[date_df['sentiment'] == 'positive']['Content'].tolist())
wordcloud = WordCloud(width=800, height=400).generate(positive_words)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Sentiment Word Cloud - Facebook Date_df')
plt.show()

negative_words = ' '.join(date_df[date_df['sentiment'] == 'negative']['Content'].tolist())
wordcloud = WordCloud(width=800, height=400).generate(negative_words)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Sentiment Word Cloud - Facebook Date_df')
plt.show()

# %%
# prompt: delete the rows of the dataframe where there is nan in both column topComments_0_poster and topComments_1_poster
df_network = date_df.copy()
df_network = df_network.dropna(subset=['topComments_0_poster', 'topComments_1_poster'])

# %%
df_network.isnull().sum()
df_network.shape
# Out:
# (206, 17)

# %%
interactions = []

for index, row in df_network.iterrows():
    if pd.notnull(row['topComments_0_poster']):
        interactions.append((row['Poster'], row['topComments_0_poster']))
    if pd.notnull(row['topComments_1_poster']):
        interactions.append((row['Poster'], row['topComments_1_poster']))

# %%
interactions

# %%
import networkx as nx

# Initialize an empty graph
G = nx.Graph()

# Add edges to the graph from your interactions list
G.add_edges_from(interactions)

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))
nx.draw_networkx(G, with_labels=False, node_size=20, font_size=10, node_color='skyblue', edge_color='gray')
plt.title('Network of Interactions between Posters and Commenters')
plt.axis('off')
plt.show()

# %%
import networkx as nx
degree_centrality = nx.degree_centrality(G)
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True)

top_nodes_by_degree_centrality = sorted_degree_centrality[:10]  # Top 10 nodes
top_nodes_by_degree_centrality
# Out:
# [('Scott Clouthier', 0.022026431718061675),
#  ('Terry Dean Shott', 0.015418502202643174),
#  ('Loreen Beav', 0.015418502202643174),
#  ('Dorothy Laviolette', 0.015418502202643174),
#  ('Myrna Lynette', 0.011013215859030838),
#  ('Keyna Norwegian', 0.011013215859030838),
# 104                      1.0              Lucy Bro
# 125                      2.0       Scott Clouthier
# 147                      1.0           Jamie Marie
# 165                      0.0     Stella Wasylyshyn
# 170                      0.0           Loreen Beav
# 176                      0.0     Dawnalynn Poitras
# 188                      0.0            Missy Love
# 208                      9.0             Jen Berry
# 222                      2.0          Nicola Jones
# 260                      1.0       Bonnie Deschene
# 273                      0.0       Scott Clouthier
# 315                      0.0            Carl Rymer
# 350                      0.0    Martina Zoe-Martin
# 368                      0.0         Margo Ziemann
#
#                                  topComments_1_content sentiment
# 8    I'm in Steen river only place I had decent ser...  negative
# 10   Thank you Loreen Beav for sharing information....   neutral
# 11                               Wow thats awesome! 👏👏   neutral
# 18                         Who are you to ask please ?   neutral
# 36                                           🌧️🌦️☔️💧🙏👏  positive
# 41   Keyna Norwegian Yes my grandma Delphine is saf...   neutral
# 104                                            Pm send   neutral
# 125  The group Edmonton Upcycling Parents is allowi...   neutral
# 147  Hey Myrna, are you and your family still in th...  positive
# 165                                   Very thoughtful!  positive
# 170  https://www.facebook.com/100064861953345/posts...   neutral
# 176                                                NaN   neutral
# 188                         Let your uncle Tobie know.   neutral
# 208  Prayers for all in NWT. My sister and family a...   neutral
# 222  I am staying at the holiday inn and suites. I ...   neutral
# 260  And do not panic if google takes you to the gr...   neutral
# 273  I actually can’t see it yet. But a friend chec...   neutral
# 315                      There's gas but you need cash  negative
# 350  Is this for South slave evacuees only or for a...   neutral
# 368                                   That’s great❤️❤️   neutral

# %%
# Extract the egocentric network for "Scott Clouthier"
scott_neighbors = list(G.neighbors('Scott Clouthier'))
scott_subgraph = G.subgraph(scott_neighbors + ['Scott Clouthier'])

# Visualize Scott Clouthier's egocentric network
plt.figure(figsize=(8, 8))
nx.draw_networkx(scott_subgraph, with_labels=True, node_size=50, node_color='orange', font_size=8)
plt.title('Egocentric Network of Scott Clouthier')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

top_nodes = [node[0] for node in top_nodes_by_degree_centrality]

fig, axes = plt.subplots(2, 5, figsize=(15, 10))

# Iterate through the top 10 nodes and draw their egocentric networks
for i, node in enumerate(top_nodes):
    neighbors = list(G.neighbors(node))
    subgraph = G.subgraph(neighbors + [node])
    ax = axes[i // 5, i % 5]
    nx.draw_networkx(subgraph, with_labels=True, node_size=50, node_color='orange', font_size=8, ax=ax)
    ax.set_title(node)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Calculate betweenness centrality for the network
betweenness_centrality = nx.betweenness_centrality(G)

# Sort nodes by betweenness centrality
sorted_betweenness = sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse=True)

# Get the top nodes with the highest betweenness centrality
top_nodes_by_betweenness = sorted_betweenness[:10]  # Top 10 nodes
top_nodes_by_betweenness
# Out:
# [('Ann Lepine', 0.003841254096527312),
#  ('Michelle Scott', 0.003432816952086433),
#  ('Jessie Lulu Teed', 0.003325845319018584),
#  ('Loreen Beav', 0.003209148992035476),
#  ('Scott Clouthier', 0.0029854810319845187),
#  ('Bonnie Deschene', 0.0024214487848994953),
#  ('Myrna Lynette', 0.0023825500092384596),
#  ('Queeny Ann Flores', 0.002246404294424833),
#  ('Sonia L. Beaulieu', 0.0017990683743229184),
#  ('Wendy Dumas', 0.0017115461290855873)]

# %%
# Identify dates with significant peaks in sentiment
positive_peaks = date_df[date_df['sentiment'] == 'positive'].groupby('time').size().sort_values(ascending=False).head(5)
negative_peaks = date_df[date_df['sentiment'] == 'negative'].groupby('time').size().sort_values(ascending=False).head(5)
print(positive_peaks)
print(negative_peaks)
# Out:
# time
# Aug 18    24
# Aug 17    17
# Aug 14    12
# Aug 19     7
# Aug 16     6
# dtype: int64
# time
# Aug 17    7
# Aug 15    2
# Aug 18    2
# Aug 16    1
# Aug 19    1
# dtype: int64

# %%
peak_dates = list(positive_peaks.index) + list(negative_peaks.index)
df_peaks = date_df[date_df['time'].isin(peak_dates)]
df_peaks_positive = df_peaks[df_peaks['sentiment'] == 'positive']
df_peaks_negative = df_peaks[df_peaks['sentiment'] == 'negative']

# %%
df_peaks_positive
# Out:
#                       Poster  Comments  Reactions    time  Reposts  \
# 0             Michelle Scott         7         94  Aug 15        0
# 1     Paulette Planidin West        11         68  Aug 14        0
# 7             Karen Simmonds         5         73  Aug 17        0
# 16              Sharon Miron         4         17  Aug 15        0
# 20           Ann Beaudriault         6         59  Aug 15        0
# ..                       ...       ...        ...     ...      ...
# 369             Sandy Cowger         2         31  Aug 17        0
# 372              Loreen Beav         0          5  Aug 17        0
# 388              Annie Goose         0          3  Aug 17        0
# 391          Jennifer Foster         0          4  Aug 17        0
# 392  Jane Ostler Groenewegen        18        257  Aug 16        0
#
#                                                Content  \
# 0                               daniel scott made safe
# 1    brian teagan oh snoopy safe grimshaw night bro...
# 7    former accommodate anyone nwt evacuating manit...
# 16   sharon miron fort smith safely spruce grove tw...
# 20   mom betty hubby john logan markus doggos safe ...
# ..                                                 ...
# 369  natalie linehan grayson ferguson marcy cowger ...
# 372  attention travellers‼️ peace river blue star t...
# 388  daughter andrea goose safe waiting travel sir ...
# 391                       updatetravel arranged lucky💕
# 392  jane ostler groenewegen high level since sunda...
#
#      topComments_0_comments        topComments_0_time  \
# 0                       NaN  2023-08-15T00:58:13.000Z
# 1                       NaN  2023-08-14T09:28:55.000Z
# 7                       2.0  2023-08-29T21:12:56.000Z
# 16                      3.0  2023-08-28T02:54:15.000Z
# 20                      1.0  2023-08-15T06:04:46.000Z
# ..                      ...                       ...
# 369                     NaN  2023-08-17T03:04:54.000Z
# 372                     NaN                       NaN
# 388                     NaN                       NaN
# 391                     NaN                       NaN
# 392                     NaN  2023-08-16T14:21:49.000Z
#
#      topComments_0_reactions topComments_0_poster  \
# 0                        0.0        Myrna Lynette
# 1                        1.0       Tracy Therrien
# 7                        2.0           Kate Hearn
# 16                       1.0          Karen Willy
# 20                       2.0   Jaylenn Tourangeau
# ..                       ...                  ...
# 369                      0.0           Vita Morin
# 372                      NaN                  NaN
# 388                      NaN                  NaN
# 391                      NaN                  NaN
# 392                      9.0       Jane Balsillie
#
#                                  topComments_0_content  \
# 0                                             Woohoo❤️
# 1                                     Good to hear. ❤️
# 7    Hi Karen! Shucks-it would have been nice to se...
# 16                    I’m glad you and family are safe
# 20              I live here hon. I sent you a message.
# ..                                                 ...
# 369                                          Thank God
# 372                                                NaN
# 388                                                NaN
# 391                                                NaN
# 392  Yes 👍🏻 Jane G. Thanks for all your generosity ...
#
#      topComments_1_comments        topComments_1_time  \
# 0                       NaN  2023-08-15T01:09:10.000Z
# 1                       1.0  2023-09-07T20:38:09.000Z
# 7                       1.0  2023-08-30T17:51:48.000Z
# 16                      NaN                       NaN
# 20                      NaN  2023-08-15T06:13:48.000Z
# ..                      ...                       ...
# 369                     NaN  2023-08-17T17:57:30.000Z
# 372                     NaN                       NaN
# 388                     NaN                       NaN
# 391                     NaN                       NaN
# 392                     NaN                       NaN
#
#      topComments_1_reactions topComments_1_poster  \
# 0                        0.0     Barb Hunt-Atwell
# 1                        0.0           Vita Morin
# 7                        1.0      Stephanie Yuill
# 16                       NaN                  NaN
# 20                       2.0        Bobby Bourque
# ..                       ...                  ...
# 369                      0.0        Linda Sanguez
# 372                      NaN                  NaN
# 388                      NaN                  NaN
# 391                      NaN                  NaN
# 392                      NaN                  NaN
#
#                                  topComments_1_content sentiment
# 0                                                   🥰💞  positive
# 1                Are you here in Peace River Paulette?  positive
# 7    Hi Karen! Can you book me in for Christmas?😂😂\...  positive
# 16                                                 NaN  positive
# 20   Go to the GP Alliance Church to register and s...  positive
# ..                                                 ...       ...
# 369                                           ❤️❤️🙏🙏🙏🙏  positive
# 372                                                NaN  positive
# 388                                                NaN  positive
# 391                                                NaN  positive
# 392                                                NaN  positive
#
# [70 rows x 17 columns]

# %%
df_peaks_negative
# Out:
#                     Poster  Comments  Reactions    time  Reposts  \
# 8         Terry Dean Shott        10         42  Aug 17        0
# 28            Linda Carman         5          1  Aug 15        0
# 78           Rosalie Heron        37        109  Aug 17        0
# 122          Tasha Lavinia         8         25  Aug 17        0
# 159        Sherry Reynolds         0          3  Aug 19        0
# 160  Karen Pears Poppleton         6          2  Aug 18        0
# 185            Lee Suzanna         4          5  Aug 18        0
# 218          Elaine DeBock         4         43  Aug 17        0
# 315             Roy Fabian         2          6  Aug 16        0
# 359     Phoebe Jeffreyevna         1          9  Aug 17        0
# 363           Kendra Gaede         6          3  Aug 17        0
# 397         Melissa Fraser         1         16  Aug 15        0
# 398         Therese Morris         0          2  Aug 17        0
#
#                                                Content  \
# 8                               ft prov traffic yk nut
# 28   found faye stark hate ask someone check cambri...
# 78   northern evacuee got kicked told leave even ev...
# 122  lineup gas fort prov crazy right ahead traffic...
# 159  ’ calgary room available townhouse evacuee cou...
# 160        free fuel stop high level diesel gas convoy
# 185  barrhead inn suite room available called check...
# 218  dont know appropriate place post former reside...
# 315  carl rymer safe deninu kue sent message saying...
# 359  host people apartment vancouver fire evacuee b...
# 363  edit closed he coming edmonton hell staying ni...
# 397  please understand registered edmonton please m...
# 398                useful source info ab mibextidnifoz
#
#      topComments_0_comments        topComments_0_time  \
# 8                       3.0  2023-08-17T22:32:17.000Z
# 28                      NaN  2023-08-15T16:21:51.000Z
# 78                      1.0  2023-08-17T17:54:39.000Z
# 122                     NaN  2023-08-17T08:08:15.000Z
# 159                     NaN                       NaN
# 160                     NaN  2023-08-18T22:30:44.000Z
# 185                     NaN  2023-08-18T16:42:11.000Z
# 218                     NaN  2023-08-18T07:05:35.000Z
# 315                     NaN  2023-08-16T18:35:08.000Z
# 359                     NaN  2023-08-17T18:36:10.000Z
# 363                     1.0  2023-08-17T04:22:57.000Z
# 397                     NaN                       NaN
# 398                     NaN                       NaN
#
#      topComments_0_reactions   topComments_0_poster  \
# 8                        4.0            Patti Bligh
# 28                       1.0       Chelsea Simister
# 78                       8.0             Tara Woods
# 122                      1.0            Tekay Tikay
# 159                      NaN                    NaN
# 160                      0.0  Karen Pears Poppleton
# 185                      1.0       Margo Mandeville
# 218                      2.0      Noeline Villebrun
# 315                      0.0        Theresa Studney
# 359                      0.0           Wendy Sutton
# 363                      0.0           Kendra Gaede
# 397                      NaN                    NaN
# 398                      NaN                    NaN
#
#                                  topComments_0_content  \
# 8    If you don’t need gas or can make it to steen ...
# 28   Misty Bloomstrand is going to people's houses,...
# 78                   Leave a review on Google as well!
# 122           Praying for safety out fellow YKnifers 🙏
# 159                                                NaN
# 160  Thank you!!  Just leaving manning,  thought I ...
# 185                                          Thank you
# 218       Ill copy & post on my page. Thank You!🌹❤️🙏🏽🦅
# 315  https://m.facebook.com/story.php?story_fbid=66...
# 359  Those evacuated that are towing campers or hav...
# 363  Edit: Also looking for any recommendations for...
# 397                                                NaN
# 398                                                NaN
#
#      topComments_1_comments        topComments_1_time  \
# 8                       NaN  2023-08-17T22:40:32.000Z
# 28                      1.0  2023-08-25T22:34:42.000Z
# 78                      NaN  2023-08-17T18:04:00.000Z
# 122                     NaN  2023-08-19T15:51:31.000Z
# 159                     NaN                       NaN
# 160                     NaN  2023-08-19T00:57:17.000Z
# 185                     NaN  2023-08-18T16:45:34.000Z
# 218                     NaN  2023-08-18T16:01:25.000Z
# 315                     NaN  2023-08-17T22:37:00.000Z
# 359                     NaN                       NaN
# 363                     NaN  2023-08-17T07:03:45.000Z
# 397                     NaN                       NaN
# 398                     NaN                       NaN
#
#      topComments_1_reactions topComments_1_poster  \
# 8                        1.0     Terry Dean Shott
# 28                       6.0          Dalke Ellen
# 78                      12.0       Melissa Fraser
# 122                      1.0       Juner Michelin
# 159                      NaN                  NaN
# 160                      2.0      Jerome Constant
# 185                      1.0          Lee Suzanna
# 218                      0.0      Robin Alexandra
# 315                      0.0           Carl Rymer
# 359                      NaN                  NaN
# 363                      0.0   Danielle Elizabeth
# 397                      NaN                  NaN
# 398                      NaN                  NaN
#
#                                  topComments_1_content sentiment
# 8    I'm in Steen river only place I had decent ser...  negative
# 28   She’s at a hotel called dunvegan motor inn in ...  negative
# 78   Please make your way to the Leduc Recreation C...  negative
# 122  Tasha Lavinia free gas/diesel bottled water at...  negative
# 159                                                NaN  negative
# 160  Drive safe, it’s raining here in Edmonton and ...  negative
# 185  Its a lovely little town close enough to Edmonton  negative
# 218                                         Amy Stuart  negative
# 315                      There's gas but you need cash  negative
# 359                                                NaN  negative
# 363                           Omg u guys can come here  negative
# 397                                                NaN  negative
# 398                                                NaN  negative

# %%
# Calculate the number of posts per day
posts_per_day = date_df.groupby('time')['Content'].count()

# Calculate the average number of reactions and comments per post
avg_reactions_per_post = date_df.groupby('time')['Reactions'].mean()
avg_comments_per_post = date_df.groupby('time')['Comments'].mean()

# Plot the time series of posts, reactions, and comments
fig, axes = plt.subplots(3, 1, figsize=(12, 10))

posts_per_day.plot(ax=axes[0], label='Number of Posts')
axes[0].set_title('Number of Posts per Day')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Number of Posts')

avg_reactions_per_post.plot(ax=axes[1], label='Average Reactions per Post')
axes[1].set_title('Average Reactions per Post')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Average Reactions')

avg_comments_per_post.plot(ax=axes[2], label='Average Comments per Post')
axes[2].set_title('Average Comments per Post')
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Average Comments')

plt.tight_layout()
plt.show()

# %%
# see what sentiment may have more reactions and comments

df = date_df.groupby('sentiment')[['Reactions', 'Comments']].mean()
df.plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Average Reactions and Comments by Sentiment')
plt.xlabel('Average')
plt.ylabel('Sentiment')
plt.show()

# %% [markdown]
# https://globalnews.ca/news/9907198/nwt-wildfires-yellowknife-august-19/
# An evacuation order issued Wednesday for Yellowknife, a city of 20,000, had a deadline of Friday noon, and RCMP were going door to door urging people to leave.
# https://www.yellowknife.ca/en/news/obey-the-evacuation-order.aspx
# https://www.yellowknife.ca/en/news/city-of-yellowknife-issues-state-of-local-emergency.aspx
# https://www.yellowknife.ca/en/news/yellowknife-preparing-for-phased-re-entry.aspx
#
# Timeline:
#
# 1.   Aug 14 - State of Local Emergency
# 2.   Aug 16 - evacuation annonucement
# 1.   Aug 18 - deadline for evacuation
# 2.   Aug 28 - Preparing for Phased Re-Entry
# 1.   Sep 04 - Sep 06 Return
# 2.   列表项

# %%
safety_evacuation = [
    "evacuation",
    "evacuated",
    "evacuate",
    "evacuaee",
    "safe",
    "shelter",
    "rescue",
    "escape"
]
Community_Support = [
    "donations",
    "volunteers",
    "fundraising",
    "support",
    "aid",
    "help",
    "accommodation",
    "service",
    "commnuity"
]
recovery_return = [
    "return",
    "back",
    "returned",
    "returning",
    "rebuilding",
    "recovery plans",
    "restoration",
    "restore"
]

# %%
# Count Keyword Occurrences Over Time for each categories in a subplot

fig, axes = plt.subplots(3, 1, figsize=(12, 10))

# Safety and Evacuation
df_safety = date_df[date_df['Content'].str.contains('|'.join(safety_evacuation), case=False, regex=True)]
df_safety_count = df_safety.groupby('time').size()
df_safety_count.plot(ax=axes[0], label='Safety and Evacuation')
axes[0].set_title('Keyword Occurrences Over Time - Safety and Evacuation')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Count')

# Community Support
df_support = date_df[date_df['Content'].str.contains('|'.join(Community_Support), case=False, regex=True)]
df_support_count = df_support.groupby('time').size()
df_support_count.plot(ax=axes[1], label='Community Support')
axes[1].set_title('Keyword Occurrences Over Time - Community Support')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Count')

# Recovery and Return
df_recovery = date_df[date_df['Content'].str.contains('|'.join(recovery_return), case=False, regex=True)]
df_recovery_count = df_recovery.groupby('time').size()
df_recovery_count.plot(ax=axes[2], label='Recovery and Return')
axes[2].set_title('Keyword Occurrences Over Time - Recovery and Return')
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# find the min and max date
min_date = date_df['time'].min()
max_date = date_df['time'].max()
print('The minimum date is:', min_date)
print('The maximum date is:', max_date)
# Out:
# The minimum date is: Aug 14
# The maximum date is: Sep 06
